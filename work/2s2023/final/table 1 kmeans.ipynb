# %%
import numpy as np
from sklearn.manifold import MDS
from matplotlib import pyplot as plt

X = np.array([[217,	139,	80,	0.33,	4,	35,	3.7],
              [197,	197,	60,	0.15,	3.5,30,	3.7],
              [240,	176,	60,	0.15,	3,	20,	3.7],
              [240,	186,	40,	0.16,	2,	15,	3.7]])


from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3,  random_state=0)
kmeans.fit(X)
print(kmeans.cluster_centers_)
print(kmeans.labels_)

import matplotlib.pyplot as plt
import numpy as np

# X = np.array(x)
plt.scatter(X[:,0],X[:,1], c=kmeans.labels_, cmap="rainbow")
plt.show()
# Out:
# [[2.40e+02 1.81e+02 5.00e+01 1.55e-01 2.50e+00 1.75e+01 3.70e+00]
#  [1.97e+02 1.97e+02 6.00e+01 1.50e-01 3.50e+00 3.00e+01 3.70e+00]
#  [2.17e+02 1.39e+02 8.00e+01 3.30e-01 4.00e+00 3.50e+01 3.70e+00]]
# [2 1 0 0]
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
